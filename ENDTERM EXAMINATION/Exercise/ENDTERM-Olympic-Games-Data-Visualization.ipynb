# %% [markdown]
# # ENDTERM EXAMINATION: <br> Olympic Games Data Analysis (1896-2016): Trends in Athlete Demographics, Performance, and Participation <hr style = "border: 2.5px solid #ff33a5"></hr>

# %% [markdown]
# Name: **Pia Mae D. Tolentino** <br>
# Course and Section: **BSCpE-2A**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"..\Raw\athlete_events-cleaned.csv", 
                 delimiter=",")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6122 entries, 0 to 6121
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Athlete_Name         6122 non-null   object
#  1   Athlete_Sex          6122 non-null   object
#  2   Athlete_Age          6122 non-null   float64
#  3   Athlete_Height (cm)  6122 non-null   float64
#  4   Athlete_Weight (Kg)  6122 non-null   float64
#  5   Team                 6122 non-null   object
#  6   NOC                  6122 non-null   object
#  7   Games                6122 non-null   object
#  8   Year                 6122 non-null   int64
#  9   Season               6122 non-null   object
#  10  City                 6122 non-null   object
#  11  Sport                6122 non-null   object
#  12  Event                6122 non-null   object
#  13  Medal                6122 non-null   object
#  14  Athlete_Height       6122 non-null   float64
# ...

# %% [markdown]
# ## Dataset Summary

# %%
df.describe()
# Out:
#        Athlete_Age  Athlete_Height (cm)  Athlete_Weight (Kg)         Year  \
# count  6122.000000          6122.000000          6122.000000  6122.000000
# mean     25.151911           175.309703            70.665142  1989.653708
# std       5.522684            10.451050            14.332667    19.988503
# min      13.000000           136.000000            28.000000  1900.000000
# 25%      21.000000           168.000000            60.000000  1976.000000
# 50%      24.000000           175.000000            70.000000  1992.000000
# 75%      28.000000           182.000000            80.000000  2006.000000
# max      65.000000           217.000000           170.000000  2016.000000
#
#        Athlete_Height  Athlete_Weight
# count     6122.000000     6122.000000
# mean       175.309703       70.665142
# std         10.451050       14.332667
# min        136.000000       28.000000
# 25%        168.000000       60.000000
# 50%        175.000000       70.000000
# ...

# %%
df_p = df.copy()

# %% [markdown]
# ## Trends in Key Columns

# %% [markdown]
# ### Unique Sports

# %%
sport_count = df_p["Sport"].value_counts()
print(sport_count)

type(sport_count)
# Out:
# Sport
# Athletics                    951
# Gymnastics                   564
# Swimming                     535
# Rowing                       256
# Cross Country Skiing         250
# Shooting                     215
# Cycling                      212
# Fencing                      200
# Alpine Skiing                194
# Canoeing                     167
# Biathlon                     157
# Wrestling                    153
# Ice Hockey                   152
# Football                     143
# Equestrianism                136
# Sailing                      136
# Hockey                       133
# Speed Skating                126
# Boxing                       113
# Basketball                    99
# Judo                          97
# Volleyball                    92
# Weightlifting                 86
# Handball                      82
# Water Polo                    75
# Ski Jumping                   62
# Diving                        59
# Tennis                        57
# ...

# %% [markdown]
# ### Unique Countries

# %%
noc_count = df_p["NOC"].value_counts()
print(noc_count)

type(noc_count)
# Out:
# NOC
# USA    426
# FRA    250
# GBR    243
# ITA    229
# CAN    229
#       ...
# TJK      1
# VIN      1
# ASA      1
# MTN      1
# MLT      1
# Name: count, Length: 184, dtype: int64
# pandas.core.series.Series

# %% [markdown]
# ### Unique Events

# %%
event_count = df_p["Event"].value_counts()
print(event_count)

type(event_count)
# Out:
# Event
# Ice Hockey Men's Ice Hockey                 126
# Football Men's Football                     107
# Hockey Men's Hockey                          81
# Basketball Men's Basketball                  72
# Water Polo Men's Water Polo                  64
#                                            ...
# Cycling Men's Madison                         1
# Athletics Women's Pole Vault                  1
# Shooting Mixed Running Target, 50 metres      1
# Judo Men's Open Class                         1
# Cycling Men's Road Race, Team                 1
# Name: count, Length: 484, dtype: int64
# pandas.core.series.Series

# %% [markdown]
# ## Age Distribution of Athletes

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
sns.histplot(df_p["Athlete_Age"].dropna(), bins = 50, kde = True, color = "#ff33a5")
plt.title("Age Distribution of Olympic Athletes",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Olympic Athletes' Age",
           fontweight = 'bold')
plt.ylabel("Frequency",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.show()

# %% [markdown]
# The distribution shows that most Olympic athletes are between 20 and 30 years old,
# with a peak around the mid-20s. Very young (below 15) and older athletes (above 40)
# are much less common, indicating that peak performance for most sports occurs in early adulthood.

# %% [markdown]
# ## Medal Distribution

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
sns.countplot(x = "Medal", data = df_p, order = ["Gold", "Silver", "Bronze"], 
              palette = ['#ff33a5', '#ff66c4', '#ff99d8'])
plt.title("Medal Distribution",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Medal Type",
           fontweight = 'bold')
plt.ylabel("Count",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.show()
# Out:
# C:\Users\63905\AppData\Local\Temp\ipykernel_17260\3236770480.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Medal", data = df_p, order = ["Gold", "Silver", "Bronze"],

# %% [markdown]
# The visualization shows that Bronze medals are the most awarded, followed by Silver and Gold. This is due to some sports awarding two Bronze medals per event, leading to a higher overall count.

# %% [markdown]
# ## Number of Athletes per Sport

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
df_p["Sport"].value_counts().head(15).plot(kind = 'bar', 
            color = '#ff33a5', width = 0.8)
plt.title("Top 15 Sports with Most Athletes",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Sport",
           fontweight = 'bold')
plt.ylabel("Number of Athletes",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# The chart shows the top 15 sports with the most athletes, highlighting the dominance of widely practiced and team-based sports like athletics, swimming, and gymnastics.

# %% [markdown]
# ## Athlete Participation Over the Years

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
sns.lineplot(data = df_p.groupby("Year")["Athlete_Name"].count().reset_index(), 
             x = "Year", y = "Athlete_Name", marker = "o", color = '#ff33a5')
plt.title("Athlete Participation Over the Years",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Year",
           fontweight = 'bold')
plt.ylabel("Number of Athletes",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.show()

# %% [markdown]
# The data shows the number of athletes participating in each Olympic year. It highlights fluctuations, with some years having higher participation and others experiencing declines.

# %% [markdown]
# ## Top 15 Countries by Athlete Count

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
df_p["NOC"].value_counts().head(15).plot(kind = 'bar', 
                color = '#ff33a5', width = 0.8)
plt.title("Top 15 Countries with Most Athletes",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Country (NOC)",
           fontweight = 'bold')
plt.ylabel("Number of Athletes",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# USA (United States) has the most athletes, followed by FRA (France) and GBR (Great Britain). Other countries, including ITA (Italy), CAN (Canada), GER (Germany), AUS (Australia), JPN (Japan), POL (Poland), SWE (Sweden), URS (Soviet Union), RUS (Russia), HUN (Hungary), CHN (China), and ESP (Spain), have gradually lower numbers, with Spain having the fewest among the top 15.

# %% [markdown]
# ## Height and Weight Distribution

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
sns.scatterplot(data=df_p, x = "Athlete_Height", y = "Athlete_Weight", 
                color = '#ff33a5', alpha = 0.6)
plt.title("Height vs Weight Distribution of Athletes",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Height (cm)",
           fontweight = 'bold')
plt.ylabel("Weight (Kg)",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.show()

# %% [markdown]
# The scatter plot shows a **positive correlation** between height and weight among athletes, with most data points concentrated between **160-190 cm in height** and **50-100 kg in weight**, while some outliers exceed **200 cm in height** or **160 kg in weight**.

# %% [markdown]
# ## Gender Distribution

# %%
df_p = df.copy()

plt.figure(facecolor = '#c4d1fb', figsize = (12,6))
sns.countplot(x = "Athlete_Sex", data = df_p, palette = ['#ff33a5', '#ff66c4'])
plt.title("Gender Distribution of Olympic Athletes",
          fontfamily = 'Palatino Linotype',
          fontsize = 16,
          fontweight = 'bold')
plt.xlabel("Gender",
           fontweight = 'bold')
plt.ylabel("Count",
           fontweight = 'bold')
plt.grid(True,
         color = 'gray')
plt.show()
# Out:
# C:\Users\63905\AppData\Local\Temp\ipykernel_17260\2287926825.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Athlete_Sex", data = df_p, palette = ['#ff33a5', '#ff66c4'])

# %% [markdown]
# The gender distribution of Olympic athletes shows that historically, there have been more male athletes than female athletes. However, the gap has gradually narrowed over time as more women have participated in the Games, reflecting increasing gender inclusivity in sports.

# %% [markdown]
# ## Average Age of Athletes by Year

# %%
df_p = df.copy()

df_p['Year'] = pd.to_datetime(df_p['Year'], format='%Y')
df_p_age = df_p.groupby('Year')["Athlete_Age"].mean().reset_index()
print("Average Age of Athletes by Olympic Year")
print(df_p_age.head(30))
# Out:
# Average Age of Athletes by Olympic Year
#          Year  Athlete_Age
# 0  1900-01-01    26.750000
# 1  1904-01-01    22.250000
# 2  1906-01-01    26.200000
# 3  1908-01-01    22.625000
# 4  1912-01-01    23.928571
# 5  1920-01-01    24.000000
# 6  1924-01-01    25.818182
# 7  1928-01-01    27.350000
# 8  1932-01-01    29.187500
# 9  1936-01-01    25.966667
# 10 1948-01-01    26.555556
# 11 1952-01-01    23.607843
# 12 1956-01-01    26.271605
# 13 1960-01-01    25.189723
# 14 1964-01-01    24.770677
# 15 1968-01-01    24.429878
# 16 1972-01-01    23.985075
# 17 1976-01-01    24.441696
# 18 1980-01-01    23.879668
# 19 1984-01-01    23.972509
# 20 1988-01-01    24.025316
# 21 1992-01-01    24.275949
# 22 1994-01-01    24.280000
# 23 1996-01-01    24.768786
# 24 1998-01-01    24.966667
# 25 2000-01-01    25.587940
# 26 2002-01-01    25.312500
# 27 2004-01-01    26.204433
# 28 2006-01-01    26.415493
# 29 2008-01-01    26.475325

# %% [markdown]
# ## Average Athlete Height (cm) by Year

# %%
df_height = df_p[['Year', 'Athlete_Height']].dropna()
df_height = df_height.groupby('Year')['Athlete_Height'].mean().reset_index()
print("Average Athlete Height by Year")
print(df_height.head(30))
# Out:
# Average Athlete Height by Year
#          Year  Athlete_Height
# 0  1900-01-01      177.750000
# 1  1904-01-01      178.750000
# 2  1906-01-01      177.600000
# 3  1908-01-01      179.500000
# 4  1912-01-01      175.642857
# 5  1920-01-01      177.785714
# 6  1924-01-01      178.909091
# 7  1928-01-01      176.050000
# 8  1932-01-01      173.687500
# 9  1936-01-01      175.333333
# 10 1948-01-01      178.074074
# 11 1952-01-01      175.921569
# 12 1956-01-01      173.617284
# 13 1960-01-01      172.857708
# 14 1964-01-01      173.436090
# 15 1968-01-01      173.774390
# 16 1972-01-01      174.047761
# 17 1976-01-01      174.784452
# 18 1980-01-01      175.132780
# 19 1984-01-01      175.020619
# 20 1988-01-01      175.886076
# 21 1992-01-01      175.392405
# 22 1994-01-01      173.450000
# 23 1996-01-01      176.005780
# 24 1998-01-01      174.091667
# 25 2000-01-01      175.952261
# 26 2002-01-01      174.460938
# 27 2004-01-01      177.495074
# 28 2006-01-01      175.260563
# ...

# %% [markdown]
# ## Total Medals Awarded Overtime

# %%
df_p = df.copy()

df_p= df_p[df_p["Medal"].notna()]

medals_per_year = df_p.groupby("Year")["Medal"].count().reset_index()

plt.figure(facecolor = '#c4d1fb', figsize = (12, 6))
sns.lineplot(data = medals_per_year, x = 'Year', y = 'Medal', marker = 'o', color = '#ff33ab')

plt.title("Overall Trend of Total Medals Awarded Over Time", 
          fontsize = 16, 
          fontweight = 'bold')
plt.xlabel("Olympic Year", 
           fontweight = 'bold')
plt.ylabel("Total Medals Awarded", 
           fontweight = 'bold')
plt.grid(True, linestyle = "--", alpha = 0.5)
plt.show()

# %% [markdown]
# The trend shows a steady increase in total medals awarded over time, reflecting the growth of the Olympic Games, including more sports, events, and participants.
